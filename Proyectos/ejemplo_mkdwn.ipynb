# %% [markdown]
# # Markdown Ejemplos - Título Nivel 1
# ## Tíulo Nivel 2
# ### Título Nivel 3
# #### Título Nivel 4
# ##### Título Nivel 5
# Esto es un texto normal, y ahora **en negrita** y la *cursiva* esta disponible

# %% [markdown]
# > Cita o bloque destacado
# > Para resaltar conceptos

# %% [markdown]
# ## Imagenes:
#
# ![Messi 10](data:image/jpeg;base64,...)
#
# Este es **Messi**, representante de **Argentina** en Miami USA

# %% [markdown]
# ## Codigo insertado
# Para imprimir en Python, usa `print("Hola Mundo")`.
#
# Si quiero resaltar varias lineas de codigo utilizo un bloque de codigo (code block) con tres comillas invertidas "```"
#
# ```Python
# def saludar(nombre):                    # definicion de la funcion saludar
#     print(f"hola, {nombre}!")
# saludar("Luis")
# ```
#
# Sigue texto normal

# %% [markdown]
# ## Tabla:
#
# | Ciudad        | Pais            | Lenguaje oficial  |
# |---------------|-----------------|-------------------|
# | DF            | Mexico          | Espaňol           |
# | Santiago      | Chile           | Espaňol           |
# | London        | Reino Unido ... | Inglés            |
# | Beiging       | China           | Chino mandarín    |
# | Córdoba       | Argentina       | Cordoooobes!      |
# | Colombia      | Bogota          | Espaňol           |
# | Quebec        | Canada          | Frances           |

# %% [markdown]
# ## Enlace:
#
# Para consultar la documentacion oficial:
# * [Python.org](https://www.python.org/)
# * [Jupyter.org](https://www.jupyter.org)

# %% [markdown]
# ## Listas:
#
# - Crear entorno de trabajo
#   - Instalar Python
#   - Instalar Visual Studio Code
#     - Instalar extensiones
#   - Crear la carpeta "Proyecto_G25"

# %% [markdown]
# ## Lista numerada:
#
# Tengo que comprar frutas:
# 1. Banana
# 2. Manzana
# 3. Pera
# 4. Mandarina

# %% [markdown]
# # Ahora un poco de CODIGO

# %%
print("Hola Mundo")
print("¡Te saludo afectuosamente! Espero que tengas un gran día 😊")

# %% [markdown]
# ### Este codigo... va a funcionar??

# %%
nombre = input("¿Cuál es tu nombre? ")
edad = int(input("¿Cuántos años tienes? "))

if edad < 13:
    generacion = "Generación Alfa"
elif edad < 27:
    generacion = "Generación Z"
elif edad < 42:
    generacion = "Millennial"
elif edad < 57:
    generacion = "Generación X"
elif edad < 77:
    generacion = "Baby Boomer"
else:
    generacion = "Generación Silenciosa"

print(f"{nombre}, perteneces a la {generacion}.")
# Out:
# ¿Cuál es tu nombre?  Joan
# ¿Cuántos años tienes?  27
# Joan, perteneces a la Millennial.

# %%
# Declaración de variables de distintos tipos
numero_entero = 42
numero_decimal = 3.14
texto = "Hola, Jupyter!"
booleano = True
lista = [1, 2, 3, 4]
diccionario = {"nombre": "Luis", "edad": 35}

# %%
# Ejemplos de uso con tipo
print(f"El número entero es: {numero_entero} (tipo: {type(numero_entero)})")
print(f"El número decimal es: {numero_decimal} (tipo: {type(numero_decimal)})")
print(f"El texto es: {texto} (tipo: {type(texto)})")
print(f"El valor booleano es: {booleano} (tipo: {type(booleano)})")
print(f"La lista contiene: {lista} (tipo: {type(lista)})")
print(f"El diccionario tiene: {diccionario} (tipo: {type(diccionario)})")

# Operaciones con las variables
suma = numero_entero + numero_decimal
print(f"Suma de entero y decimal: {suma} (tipo: {type(suma)})")

texto_completo = texto + " ¿Cómo estás?"
print(f"{texto_completo} (tipo: {type(texto_completo)})")

lista.append(5)
print(f"Lista actualizada: {lista} (tipo: {type(lista)})")

diccionario["pais"] = "Argentina"
print(f"Diccionario actualizado: {diccionario} (tipo: {type(diccionario)})")

# %% [markdown]
# ## Grafico:

# %%
import matplotlib.pyplot as plt

# Datos de ejemplo: estatura (cm) y peso (kg) de 10 personas
estatura = [160, 165, 170, 175, 180, 155, 168, 172, 178, 182]
peso = [60, 65, 70, 75, 80, 55, 68, 72, 78, 85]

plt.scatter(estatura, peso, color='blue')
plt.title('Correlación entre Estatura y Peso')
plt.xlabel('Estatura (cm)')
plt.ylabel('Peso (kg)')
plt.grid(True)
plt.show()

# %%
so')
plt.xlabel('Estatura (cm)')
plt.ylabel('Peso (kg)')
plt.grid(True)
plt.show()

# %%
# Instalar Matplotlib si no está instalado
# !pip install matplotlib

# %%
nombre_usuario = input("¿Cuál es tu nombre? ")
print(f"¡Hola, {nombre_usuario}! Te saludo cordialmente 😊")
# Out:
# ¡Hola, luiso! Te saludo cordialmente 😊
